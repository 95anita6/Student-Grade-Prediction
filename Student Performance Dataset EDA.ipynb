# %% [markdown]
# #### This data approach student achievement in secondary education of two Portuguese schools.
# #### The data attributes include student grades, demographic, social and school related features) and
# #### it was collected by using school reports and questionnaires

# %%
import pandas as pd
import numpy as np

# %%
data_file = r'C:\Users\AnitaM\Downloads\student-por.csv'
sp = pd.read_csv(data_file)
sp.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
sp.shape
# Out:
# (649, 33)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.countplot(x='sex', data=sp, hue='school', palette='Greens_d')

# %%
# 'GP' - Gabriel Pereira has more female students than in 'MS' - Mousinho da Silveira

# %%
sns.barplot(x='sex', y='age', hue='school', data=sp)
# Out:
# C:\Users\AnitaM\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sp['age'].describe()
# Out:
# count    649.000000
# mean      16.744222
# std        1.218138
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64

# %%
sns.boxplot(x='G3', y='age', data=sp)

# %%
sns.boxplot(x='G3', y='address', data=sp)

# %%
sns.barplot(x='age', y='school', hue='address', data=sp)
# Out:
# C:\Users\AnitaM\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(x='famsize', y='G3', hue='age', data=sp)

# %%
sns.countplot(x='Pstatus', data=sp, hue='G3')

# %%
# This data has more number of students having parents who live together. The distribution for both the categories is almost same.

# %%
plt.figlegend('right')
plt.figure(figsize=[20,8])
sns.countplot(x='Medu', data=sp, hue='G3')
plt.show()

# %%
# Most of the students have average grade 10-11 with mother's education being either 1-primary education (till 4th grade) and
# 2- 5th to 9th grade and the students with higher mother's education tend to have average grades 12-13.

# %%
plt.figlegend('right')
plt.figure(figsize=[20,8])
sns.countplot(x='Fedu', data=sp, hue='G3')
plt.show()

# %%
# Most students have grades 10/11/12 with father's education being 5th to 9th grade.

# %%
sns.boxplot(x='Mjob', y='G3', data=sp)

# %%
sns.boxplot(x='Fjob', y='G3', data=sp)

# %%
# Grades are good for students with mother's having job in health sector or of teacher and 
# grades are good for students with father's job as a teacher

# %%
sns.boxplot(x='traveltime', y='G3', data=sp) # travel time in mins

# %%
# For most of the students the travel time is either less than 15mins or 15-30 mins

# %%
plt.figlegend('right')
plt.figure(figsize=[20,8])
sns.countplot(x='studytime', data=sp, hue='G3')
plt.show()

# %%
# Count for students with studytime either 1 - less than 2 hrs and 2 - 2 to 5 hrs wih grades 10-11 is maximum

# %%
plt.figlegend('right')
plt.figure(figsize=[20,8])
sns.countplot(x='studytime', data=sp, hue='failures')
plt.show()

# %%
sp['failures'].value_counts()
# Out:
# 0    549
# 1     70
# 2     16
# 3     14
# Name: failures, dtype: int64

# %%
sp['studytime'].value_counts()
# Out:
# 2    305
# 1    212
# 3     97
# 4     35
# Name: studytime, dtype: int64

# %%
# More the study time less is the failure

# %%
plt.figure(figsize=[15,8])
sns.countplot(x='G3', data=sp, hue='Dalc')
plt.show()

# %%
# Most of the students have very low alcohol consumption and they fall under grades 11 and 13

# %%
sns.barplot(x='G1', y='G3', data=sp)
# Out:
# C:\Users\AnitaM\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x='G2', y='G3', data=sp)
# Out:
# C:\Users\AnitaM\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Adding a new feature : G1 and G2 taken together and these grades would have a significant in role in deciding the final grade
sp['G1_G2_together'] = sp['G1'] * sp['G2']

# %%
plt.figure(figsize=[15,8])
sns.barplot(x='G1_G2_together', y='G3', data=sp)
plt.show()
# Out:
# C:\Users\AnitaM\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# As and when the G1 and G2 grades go up, the final grade G3 also goes up.

# %%
pivot_schoolsup = sp.pivot_table(index='schoolsup', values='G3', aggfunc=np.mean)
pivot_schoolsup.head()
# Out:
#                   G3
# schoolsup
# no         11.979346
# yes        11.279412

# %%
# Not much effect of extra educational support on the grades

# %%
pivot_schoolsup = sp.pivot_table(index='famsup', values='G3', aggfunc=np.mean)
pivot_schoolsup.head()
# Out:
#                G3
# famsup
# no      11.665339
# yes     12.057789

# %%
sp['G3'].describe()
# Out:
# count    649.000000
# mean      11.906009
# std        3.230656
# min        0.000000
# 25%       10.000000
# 50%       12.000000
# 75%       14.000000
# max       19.000000
# Name: G3, dtype: float64

# %%
# seperate numerical and categorical features to check the relation:
num_feat = sp.select_dtypes(include=[np.number])
cat_feat = sp.select_dtypes(exclude=[np.number])

# %%
num_feat
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         0       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 644   19     2     3           1          3         1       5         4
# 645   18     3     1           1          2         0       4         3
# 646   18     1     1           2          2         0       1         1
# 647   17     3     1           2          1         0       2         4
# 648   18     3     2           3          1         0       4         4
#
#      goout  Dalc  Walc  health  absences  G1  G2  G3  G1_G2_together
# ...

# %%
cat_feat.head()
# Out:
#   school sex address famsize Pstatus     Mjob      Fjob  reason guardian  \
# 0     GP   F       U     GT3       A  at_home   teacher  course   mother
# 1     GP   F       U     GT3       T  at_home     other  course   father
# 2     GP   F       U     LE3       T  at_home     other   other   mother
# 3     GP   F       U     GT3       T   health  services    home   mother
# 4     GP   F       U     GT3       T    other     other    home   father
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0       yes     no   no         no     yes    yes       no       no
# 1        no    yes   no         no      no    yes      yes       no
# 2       yes     no   no         no     yes    yes      yes       no
# 3        no    yes   no        yes     yes    yes      yes      yes
# 4        no    yes   no         no     yes    yes       no       no

# %%
# Using correlation coefficient to find relation among the numeric features:
corr = num_feat.corr()

plt.figure(figsize=(14,14))
sns.heatmap(corr, annot=True, fmt= '.2f',annot_kws={'size': 15}, cmap= 'coolwarm')

# %%
# There is strong correlation between the grades G1,G2 and final G3 of which G2 has a stronger relation as compared to G1.
# There also seems to be strong correlation among weekday and weekend alcohol consumption but these features indiviually have negative correlation with the target variable.
# There also seems to be correlation between Father's and mother's education.
# Most of the other numeric variables seem to be in negative correlation with the target.

# %%
from scipy import stats
cat = cat_feat
def anova(frame):
    anv = pd.DataFrame()
    anv['features'] = cat.columns
    pvals = []
    for c in cat:
        samples = []
        for cls in frame[c].unique():
            s = frame[frame[c] == cls]['G3'].values
            samples.append(s)
        pval = stats.f_oneway(*samples)[1]
        pvals.append(pval)
    anv['pval'] = pvals
    return anv.sort_values('pval')

# %%
cat_feat['G3'] = sp.G3.values
k = anova(cat_feat) 
k['disparity'] = np.log(1./k['pval'].values) 
sns.barplot(data=k, x = 'features', y='disparity') 
plt.xticks(rotation=90) 
plt
# Out:
# C:\Users\AnitaM\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\AnitaM\Anaconda3\lib\site-packages\scipy\stats\stats.py:2933: RuntimeWarning: divide by zero encountered in double_scalars
#   f = msb / msw
# C:\Users\AnitaM\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# <module 'matplotlib.pyplot' from 'C:\\Users\\AnitaM\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# Relation of health and absence from school:
sns.barplot(x='absences', y='health', data=sp)
# Out:
# C:\Users\AnitaM\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# There is no relation among the absences from school and students falling ill
